# %%
import pandas as pd
df1 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/ranjitdeshmukh342@gmail.com/CpuLogData2019_09_16-2.csv",header=True,inferSchema=True)
df2 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/ranjitdeshmukh342@gmail.com/CpuLogData2019_09_17.csv",header=True,inferSchema=True)
df3 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/ranjitdeshmukh342@gmail.com/CpuLogData2019_09_18-1.csv",header=True,inferSchema=True)
df4 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/ranjitdeshmukh342@gmail.com/CpuLogData2019_09_19.csv",header=True,inferSchema=True)
df5 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/ranjitdeshmukh342@gmail.com/CpuLogData2019_09_20.csv",header=True,inferSchema=True)
df6 = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/ranjitdeshmukh342@gmail.com/CpuLogData2019_09_21.csv",header=True,inferSchema=True)

df1 = df1.toPandas()
df2 = df2.toPandas()
df3 = df3.toPandas()
df4 = df4.toPandas()
df5 = df5.toPandas()
df6 = df6.toPandas()
finaldf = pd.concat([df1, df2, df3,df4,df5,df6],ignore_index=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
finaldf.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DateTime</th>
#       <th>Cpu Count</th>
#       <th>Cpu Working Time</th>
#       <th>Cpu idle Time</th>
#       <th>cpu_percent</th>
#       <th>Usage Cpu Count</th>
#       <th>number of software interrupts since boot</th>
# ...

# %%
spark_df_new = spark.createDataFrame(finaldf)
from pyspark.sql import functions as F
renamed_df = spark_df_new.select([F.col(col).alias(col.replace(' ', '_')) for col in spark_df_new.columns])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import *
from pyspark.sql.types import *
# renamed_df.write.saveAsTable("new_data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import expr,split
from pyspark.sql import functions as F
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *



# renamed_df.head()
split_col = split(spark_df_new['Datetime'], ' ')
df9 =  spark_df_new.select('Datetime','keyboard','mouse','user_name') \
        .withColumn('Date', split_col.getItem(0))\
        .withColumn('Time', split_col.getItem(1))\
        .withColumn('Datetime',to_timestamp(spark_df_new['Datetime']))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import expr,split
from pyspark.sql import functions as F
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *
temp_table = 'latest_data'
df9.createOrReplaceTempView(temp_table)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#highst user avghours

highest_working_hours = spark.sql(""" 
                                      SELECT user_name ,from_unixtime(round((((count(user_name)*5)*60)/6),2),'H:mm:ss') as avgvalue 
                                      FROM leatest_date where keyboard !=0 OR mouse !=0 group by user_name 
                                      order by avgvalue desc
                                      """)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#ideal hours in the user
highest_idle_hours = spark.sql(" SELECT user_name ,count(*) no_of_times ,from_unixtime(round((((count(*)*5)*60)/6),2),'H:mm:ss') as ideal_value FROM leatest_date where keyboard ==0 AND mouse ==0 group by user_name order by ideal_value desc")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#lowest user avghours

lowest_working_hours = spark.sql(" SELECT user_name ,from_unixtime(round((((count(user_name)*5)*60)/6),2),'H:mm:ss') as avgvalue FROM leatest_date where keyboard !=0 OR mouse !=0 group by user_name order by avgvalue asc")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Login time of each day
session_start_time = sqlContext.sql("SELECT Date,to_timestamp(Min(Time)) min_time FROM latest_data GROUP BY Date ORDER BY Date")
temp_table = "session_start_time_table"
session_start_time.createOrReplaceTempView(temp_table)
display(session_start_time)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>min_time</th></tr></thead><tbody><tr><td>2019-09-16</td><td>2021-05-16T12:55:01.000+0000</td></tr><tr><td>2019-09-17</td><td>2021-05-16T08:25:01.000+0000</td></tr><tr><td>2019-09-18</td><td>2021-05-16T08:30:01.000+0000</td></tr><tr><td>2019-09-19</td><td>2021-05-16T08:40:02.000+0000</td></tr><tr><td>2019-09-20</td><td>2021-05-16T09:05:01.000+0000</td></tr><tr><td>2019-09-21</td><td>2021-05-16T09:10:01.000+0000</td></tr></tbody></table></div>

# %%
# Login time of each day
session_start_time = sqlContext.sql("SELECT Date,to_timestamp(Min(DateTime)) min_time FROM latest_data GROUP BY Date ORDER BY Date")
temp_table = "session_start_time_table"
session_start_time.createOrReplaceTempView(temp_table)
display(session_start_time)

#User active time
user_active_time = sqlContext.sql("SELECT user_name,Date,to_timestamp(Min(DateTime)) active_time From latest_data WHERE keyboard !=0 OR mouse !=0 GROUP BY user_name,Date ORDER BY Date")
temp_table_name = "user_active_time_table"
user_active_time.createOrReplaceTempView(temp_table_name)
display(user_active_time)
start_login = sqlContext.sql("SELECT user_active_time_table.active_time,session_start_time_table.min_time FROM user_active_time_table,session_start_time_table WHERE user_active_time_table.Date=session_start_time_table.Date")
display(start_login)

# Finding users with highest number of times late commings
highest_late_comings = sqlContext.sql("SELECT td.user_name,from_unixtime(Round((Sum(td.diff_time))/6,2),'HH:mm')AS avg_time,count(*) As no_of_times_late FROM(SELECT user_active_time_table.user_name,(unix_timestamp(user_active_time_table.active_time)- unix_timestamp(session_start_time_table.min_time))diff_time FROM user_active_time_table,session_start_time_table WHERE user_active_time_table.Date=session_start_time_table.Date) AS td WHERE td.diff_time !=0 GROUP BY td.user_name ORDER BY avg_time desc")
display(highest_late_comings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>min_time</th></tr></thead><tbody><tr><td>2019-09-16</td><td>2019-09-16T12:55:01.000+0000</td></tr><tr><td>2019-09-17</td><td>2019-09-17T08:25:01.000+0000</td></tr><tr><td>2019-09-18</td><td>2019-09-18T08:30:01.000+0000</td></tr><tr><td>2019-09-19</td><td>2019-09-19T08:40:02.000+0000</td></tr><tr><td>2019-09-20</td><td>2019-09-20T09:05:01.000+0000</td></tr><tr><td>2019-09-21</td><td>2019-09-21T09:10:01.000+0000</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
# ...

# %%
container_name = "hadoopcluster01"
storage_account_name = "hadooprestorage"
sas = "https://hadooprestorage.blob.core.windows.net/hadoopcluster01?sp=racwdl&st=2021-05-16T08:00:08Z&se=2021-05-16T16:00:08Z&spr=https&sv=2020-02-10&sr=c&sig=MX%2FhqMkRapCIqBE%2FiCHRURcRLPcba3t8UIDfkPpt0oQ%3D"
url = "wasbs://" + container_name + "@" + storage_account_name + ".blob.core.windows.net"
config = "fs.azure.sas." + container_name + "." + storage_account_name + ".blob.core.windows.net"

dbutils.fs.mount(  
  source = url,
  mount_point = "/mnt/mount21",
  extra_configs = {config:sas}
)
storage_account_access_key="BqZk/xswk88d8OgiSdB5xjIVi/V7b0FWlDBumiAEj2i3xNYNrH4QNLkt/k4RrP5SkdMD+7RsVGJHeLCmI9Lvqg=="
spark.conf.set(
  "fs.azure.account.key."+storage_account_name+".blob.core.windows.net",
  storage_account_access_key)

file_path = "wasbs://"+str(container_name)+"@"+str(storage_account_name)+".blob.core.windows.net/"
highest_working_hours.write.mode("overwrite").format("csv").option("header",True).save(file_path+"highest_working_hours")
lowest_working_hours.write.mode("overwrite").format("csv").option("header",True).save(file_path+"lowest_working_hours")
highest_idle_hours.write.mode("overwrite").format("csv").option("header",True).save(file_path+"highest_idle_hours")
highest_late_comings.write.mode("overwrite").format("csv").option("header",True).save(file_path+"highest_late_comings")
